# %%
import pandas as pd
import os
import xlsxwriter

# %%
df = pd.read_excel('./学情反馈解决方案/z.xlsx')

# %%
df
# Out:
#        班级 账号类型                上课账号        昵称        绑定手机号               学员uid  \
# 0   34754   qq           351071512      qian            -           351071512
# 1   34754   qq           485230658      qian            -           485230658
# 2   34753   qq           492771695     零落的繁华  13751555319           492771695
# 3   34754   qq           652993141      qian            -           652993141
# 4   34753   qq           762587109  gd今天司马了吗  18637228381           762587109
# ..    ...  ...                 ...       ...          ...                 ...
# 60  34753   手机  144115214304601782  prisoner  13724616003  144115214304601782
# 61  34753   微信  144115214319491489    向太阳――晟  15880051282  144115214319491489
# 62  34753   手机  144115214338946575      华sea  13680796931  144115214338946575
# 63  34753   手机  144115214532657668       宗雯吖  13763372512  144115214532657668
# 64  34753   手机  144115214542648631    樱桃抹茶糕ﾋ  15688391368  144115214542648631
#
# ...

# %%
df[df['直播时长']==df['核心课程第1节直播']+df['核心课程第2节直播']]
# Out:
#        班级 账号类型                上课账号         昵称        绑定手机号  \
# 0   34754   qq           351071512       qian            -
# 1   34754   qq           485230658       qian            -
# 3   34754   qq           652993141       qian            -
# 6   34753   qq           945669561       踏雪寻梅  18031970811
# 11  34753   qq          2018133798         寻常  15967931498
# 13  34753   qq          2293045497  为什么我就开学了呢  15951774268
# 14  34754   qq          2625118263       qian  18501969976
# 16  34753   qq          2903027429          落  18709964084
# 18  34754   qq          3014234956       qian            -
# 30  34753   微信  144115213647106434    陈ͨ三ͨ岁ͨε  13283066765
# 34  34753   手机  144115213774949835      珍惜眼前人  13408460065
# 38  34753   微信  144115213795395584         穆莫  18874486008
# 41  34753   微信  144115213820518802    就很nice啊  15393192306
# 43  34753   微信  144115213826166370      狼堡你灰哥  13934648786
# 47  34753   微信  144115213924363957       YiBo  13043875854
# ...
